# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('titanic-passengers.csv',sep = ';')
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'].isnull().value_counts()
# Out:
# False    714
# True     177
# Name: Age, dtype: int64

# %%
#Preprocessing our data

# %%
def preprocess_data(new_data):
    new_data['Age'].fillna(28,inplace=True)
    new_data.replace({'Sex':{'male': 1,'female':0}},inplace=True)
    new_data['Cabin']=new_data.Cabin.fillna('G6')
    new_data.replace({'Survived':{'Yes': 1,'No':0}},inplace=True)
    return new_data
data=preprocess_data(df)

# %%
data.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144  0.042939  0.034212 -0.057527
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.064910 -0.035322
# Pclass         -0.035144 -0.338481  1.000000  0.131900 -0.339898  0.083081
# Sex             0.042939 -0.543351  0.131900  1.000000  0.081163 -0.114631
# Age             0.034212 -0.064910 -0.339898  0.081163  1.000000 -0.233296
# SibSp          -0.057527 -0.035322  0.083081 -0.114631 -0.233296  1.000000
# Parch          -0.001652  0.081629  0.018443 -0.245489 -0.172482  0.414838
# Fare            0.012658  0.257307 -0.549500 -0.182333  0.096688  0.159651
#
#                 Parch      Fare
# PassengerId -0.001652  0.012658
# Survived     0.081629  0.257307
# Pclass       0.018443 -0.549500
# Sex         -0.245489 -0.182333
# Age         -0.172482  0.096688
# SibSp        0.414838  0.159651
# Parch        1.000000  0.216225
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.0      0
# 2                               Jensen, Mr. Hans Peder    1  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0
# 4                               Davidson, Mr. Thornton    1  31.0      1
# ..                                                 ...  ...   ...    ...
# ...

# %%
x=data[["Age", "Sex", "SibSp"]]
y= data["Survived"]

#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

#applying tree algorithm
tree = tree.DecisionTreeClassifier()  
tree.fit(x_train, y_train)   
y_pred=tree.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7821229050279329

# %%
import graphviz
dot_data=tree.export_graphviz(tree,out_file=None)
graph=graphviz.Source(dot_data)
graph.render("data")
graph
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-5dbb9c3f938b> in <module>
# ----> 1 import graphviz
#       2 dot_data=tree.export_graphviz(tree,out_file=None)
#       3 graph=graphviz.Source(dot_data)
#       4 graph.render("data")
#       5 graph
#
# ModuleNotFoundError: No module named 'graphviz'

# %%
tree2 = tree.DecisionTreeClassifier(criterion = "gini", splitter = 'random', max_leaf_nodes = 10
                                    , min_samples_leaf = 5, max_depth= 5)
model1=tree2.fit(x_train, y_train)   #fitting our model
y_pred=model1.predict(x_test)
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-542511254570> in <module>
# ----> 1 dtree = tree.DecisionTreeClassifier(criterion = "gini", splitter = 'random', max_leaf_nodes = 10
#       2                                     , min_samples_leaf = 5, max_depth= 5)
#       3 model1=dtree.fit(x_train, y_train)   #fitting our model
#       4 y_pred=model1.predict(x_test)
#       5 print("score:{}".format(accuracy_score(y_test, y_pred)))
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'DecisionTreeClassifier'

# %%
dot_data1 = tree.export_graphviz(dtree, out_file=None)
# Draw graph
graph = graphviz.Source(dot_data1) 
graph.render()
graph
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-23a54fc45a9b> in <module>
# ----> 1 dot_data1 = tree.export_graphviz(dtree, out_file=None)
#       2 # Draw graph
#       3 graph = graphviz.Source(dot_data1)
#       4 graph.render()
#       5 graph
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'export_graphviz'

# %%
clf=RandomForestClassifier(n_estimators=10)  
clf.fit(x_train, y_train)  
y_pred=clf.predict(x_test)  
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
